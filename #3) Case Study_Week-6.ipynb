# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data= pd.read_csv(r"C:\Users\Tejes\Downloads\StudentsPerformance.csv")
data.head(15)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group C            some high school  free/reduced
# 1   female        group B                 high school  free/reduced
# 2   female        group B            some high school  free/reduced
# 3   female        group B                some college      standard
# 4   female        group C                some college  free/reduced
# 5   female        group B                 high school  free/reduced
# 6   female        group B            some high school  free/reduced
# 7   female        group D          associate's degree  free/reduced
# 8   female        group D            some high school  free/reduced
# 9   female        group C                 high school      standard
# 10  female        group C            some high school  free/reduced
# 11  female        group D           bachelor's degree  free/reduced
# 12  female        group B            some high school      standard
# ...

# %%
#1 use value_counts() to give the count of vairious values
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#2 use value_counts() to give the count of vairious values
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
#3a use groupby() to create groups inside a given column and use mean() to find the average
data.groupby('gender').agg(['mean'])
# Out:
#        math score reading score writing score
#              mean          mean          mean
# gender
# female  63.376448     72.590734     72.467181
# male    68.821577     65.545643     63.446058

# %%
#3b use groupby() to create groups inside a given column and use mean() to find the average
data.groupby('test preparation course').agg(['mean'])
# Out:
#                         math score reading score writing score
#                               mean          mean          mean
# test preparation course
# completed                 69.96648     74.175978     74.684358
# none                      63.78972     66.417445     64.457944

# %%
#4a use groupby() to create groups inside a given column and use std() to find the variation
data.groupby('gender').std()
# Out:
#         math score  reading score  writing score
# gender
# female   16.029928      14.411018      14.844842
# male     14.556411      14.149594      14.227225

# %%
#4b use groupby() to create groups inside a given column and use std() to find the variation

data.groupby('test preparation course').std()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 14.521847      13.537572      13.236412
# none                      15.705689      14.608896      15.041667

# %%
#5
datx=data.groupby('math score').agg(['count'])
datx.sort_values(by='math score',ascending=False)
# Out:
#            gender race/ethnicity parental level of education lunch  \
#             count          count                       count count
# math score
# 100             7              7                           7     7
# 99              3              3                           3     3
# 98              3              3                           3     3
# 97              6              6                           6     6
# 96              3              3                           3     3
# ...           ...            ...                         ...   ...
# 18              1              1                           1     1
# 13              1              1                           1     1
# 11              1              1                           1     1
# 8               1              1                           1     1
# 0               1              1                           1     1
#
#            test preparation course reading score writing score
# ...
